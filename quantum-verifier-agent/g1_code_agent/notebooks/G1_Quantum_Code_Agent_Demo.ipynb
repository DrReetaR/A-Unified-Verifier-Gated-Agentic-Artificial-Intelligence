# %% [markdown]
# # G1 Quantum Code Agent Demo
# Run this notebook after installing the requirements.

# %%
# !pip install -q -r requirements.txt

# %%
# !python experiments/run_experiment.py

# %%
import pandas as pd
df = pd.read_csv("results/benchmark_results.csv")
df[["task_id","title","status","iterations","total_variation_distance","repair_actions"]]

# %% [markdown]
# ## Plots
# The experiment writes PNG plots to `results/plots/`.

# %%
from IPython.display import Image, display
display(Image("results/plots/pass_fail_summary.png"))
display(Image("results/plots/tvd_by_task.png"))
display(Image("results/plots/iterations_by_task.png"))
