# %% [markdown]
# # G2 Closed-Loop Quantum Agent Demo
# Run this notebook after installing requirements.

# %%
# !pip install -q -r requirements.txt

# %%
# !python experiments/run_experiment.py

# %%
import pandas as pd
pd.read_csv("results/summary_results.csv")

# %% [markdown]
# ## Output plots
# - `plots/qaoa_best_cost.png`
# - `plots/sensor_error_reduction.png`
# - `plots/sensor_uncertainty.png`
# - `plots/vqc_template_accuracy.png`
